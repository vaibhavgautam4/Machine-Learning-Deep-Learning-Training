# %%
import pandas as pd
data = pd.read_csv('Salaries.csv')
#q1(1)
data.head(10)
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_18396\2569026619.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Salaries.csv')
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# ...

# %%
#q1(2)
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
#q1(3)
data.shape
# Out:
# (148654, 13)

# %%
#q1(4)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
#q1(5)
data.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
#q1(6)
data.drop(['Id','Notes','Agency','Status'],axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %%
#q1(7)
data.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
#q1(8)
data['EmployeeName'].value_counts(ascending=False).head(5)
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %%
#q1(9)
data['JobTitle'].nunique()
# Out:
# 2159

# %%
#q1(10)
data['JobTitle'].str.contains('Captain',case=False).count()
# Out:
# 148654

# %%
#q1(11)
data[data['JobTitle'].str.contains('Fire Department')][['EmployeeName']]
# Out:
#                 EmployeeName
# 36162     Joanne Hayes-White
# 72926   Joanne M Hayes-White
# 102303        Robert E Evans
# 110535  Joanne M Hayes-White

# %%
#q1(12)
data.dtypes
#not possible to find min , max , mean
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
#q1(13)
data['EmployeeName']=data['EmployeeName'].replace(to_replace="Not provided",
                             value='NaN')
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
#q1(14)
data.drop(data[data.isnull().sum(axis=1) >=5].index ,axis=0)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
#q1(15)
data[data['EmployeeName']=='ALBERT PARDINI']#[['JobTitle']]
# Out:
#    Id    EmployeeName                         JobTitle    BasePay OvertimePay  \
# 2   3  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
#
#   OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 2  16452.6      NaN  335279.91         335279.91  2011    NaN  San Francisco
#
#   Status
# 2    NaN

# %%
#q1(16)
data[data['EmployeeName']=='ALBERT PARDINI'][['TotalPayBenefits']]
# Out:
#    TotalPayBenefits
# 2         335279.91

# %%
#for q1(12,17,18,19,20,21)
data.drop(data.index[data['BasePay'] == 'Not Provided'] , inplace=True)
data.astype({'BasePay':float}).dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
#q1(12)
data['BasePay'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [113], in <cell line: 2>()
#       1 #q1(12)
# ----> 2 data['BasePay'].min()
#
# File D:\ML\lib\site-packages\pandas\core\generic.py:11237, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11217 @doc(  # type: ignore[misc]
#   11218     _num_doc,
#   11219     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11235     **kwargs,
#   11236 ):
# > 11237     return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#
# File D:\ML\lib\site-packages\pandas\core\generic.py:10651, in NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   10643 def min(
#   10644     self,
#   10645     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10649     **kwargs,
#   10650 ):
# ...

# %%
#q1(18)

# %%
#q1(1)

# %%
#q2(1)
data = pd.read_csv('Adult.csv')
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 #q2(1)
# ----> 2 data = pd.read_csv('Adult.csv')
#       3 data.head(10)
#
# NameError: name 'pd' is not defined

# %%
#q1(2)
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
#q2(3)
data.shape
# Out:
# (48842, 15)

# %%
#q1(19)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
#q2(5)
d = data.sample(n=24421, random_state=2)
print(d)
# Out:
#        age    workclass  fnlwgt     education  educational-num  \
# 41945   47      Private  190072  Some-college               10
# 3260    31      Private  128065       HS-grad                9
# 20109   37  Federal-gov  470663  Some-college               10
# 19725   59      Private  208395       Masters               14
# 45867   35            ?  153926       HS-grad                9
# ...    ...          ...     ...           ...              ...
# 17366   30      Private  241259     Assoc-voc               11
# 11642   36      Private  177895       Masters               14
# 19211   21            ?  230397  Some-college               10
# 36255   32      Private  235847  Some-college               10
# 21772   27      Private  208703       HS-grad                9
#
#            marital-status        occupation    relationship   race  gender  \
# 41945            Divorced             Sales       Unmarried  White    Male
# ...

# %%
#q2(6)
data.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
#q2(7)
data.replace(to_replace="?",
                             value='NaN')
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#q2(8)
d = data.dropna()
d
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#q2(9)
data.sort_values("age" , inplace=True) 
data.drop_duplicates(subset="age", keep= False, inplace=False)
print(data)
# Out:
#        age workclass  fnlwgt education  educational-num marital-status  \
# 40308   86   Private  149912   Masters               14  Never-married
#
#          occupation   relationship   race  gender  capital-gain  capital-loss  \
# 40308  Adm-clerical  Not-in-family  White  Female             0             0
#
#        hours-per-week native-country income
# 40308              40  United-States  <=50K

# %%
#q2(11)
data.drop(['educational-num','capital-gain','capital-loss'],axis=1)
# Out:
#        age workclass  fnlwgt education marital-status    occupation  \
# 40308   86   Private  149912   Masters  Never-married  Adm-clerical
#
#         relationship   race  gender  hours-per-week native-country income
# 40308  Not-in-family  White  Female              40  United-States  <=50K

# %%
#q2(12)
data['age'].describe()
# Out:
# count     1.0
# mean     86.0
# std       NaN
# min      86.0
# 25%      86.0
# 50%      86.0
# 75%      86.0
# max      86.0
# Name: age, dtype: float64

# %%
#q2(13)
data[(data['age'].between(17,48))]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, educational-num, marital-status, occupation, relationship, race, gender, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
#q2(10)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 40308 to 40308
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              1 non-null      int64
#  1   workclass        1 non-null      object
#  2   fnlwgt           1 non-null      int64
#  3   education        1 non-null      object
#  4   educational-num  1 non-null      int64
#  5   marital-status   1 non-null      object
#  6   occupation       1 non-null      object
#  7   relationship     1 non-null      object
#  8   race             1 non-null      object
#  9   gender           1 non-null      object
#  10  capital-gain     1 non-null      int64
#  11  capital-loss     1 non-null      int64
#  12  hours-per-week   1 non-null      int64
#  13  native-country   1 non-null      object
#  14  income           1 non-null      object
# dtypes: int64(6), object(9)
# memory usage: 128.0+ bytes

# %%
#q2(14)
data.nunique()
# Out:
# age                1
# workclass          1
# fnlwgt             1
# education          1
# educational-num    1
# marital-status     1
# occupation         1
# relationship       1
# race               1
# gender             1
# capital-gain       1
# capital-loss       1
# hours-per-week     1
# native-country     1
# income             1
# dtype: int64

# %%
#q2(15)
import pandas as pd
d = pd.read_csv('adult.csv')
len(d[(d['education']=='Bachelors') | (d['education']=='Masters')])
# Out:
# 10682

# %%
#q2(17)
def func():
    if any(d['income'].str.contains('<=50k'))
    else 0
d['income'].apply(func)
# Out:
#   Input In [24]
#     if any(d['income'].str.contains('<=50k')) return 1
#                                               ^
# SyntaxError: invalid syntax

# %%
#q2(16)
print(d)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#q2(18)
d[d['income'].max()][['workclass']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\ML\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File D:\ML\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\ML\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '>50K'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#q2(19)
d['income']
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
#q2(20)
