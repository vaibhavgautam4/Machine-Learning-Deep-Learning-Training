# %%
# covid toy - logistic regression
# customer - ordinal encoding / label encoding
# cars - one hot encoding

import pandas as pd
d = pd.read_csv('customer.csv')

# %%
d.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
d.dtypes
# Out:
# age           int64
# gender       object
# review       object
# education    object
# purchased    object
# dtype: object

# %%
d['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
d['review'].unique()
# Out:
# array(['Average', 'Poor', 'Good'], dtype=object)

# %%
d['education'].unique()
# Out:
# array(['School', 'UG', 'PG'], dtype=object)

# %%
d['purchased'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
d['purchased'] = label_encoder.fit_transform(d['purchased'])

# %%
d['purchased'].unique()
# Out:
# array([0, 1])

# %%
d['gender'] = label_encoder.fit_transform(d['gender'])

# %%
d['gender'].unique()
# Out:
# array([0, 1])

# %%
d['review'] = label_encoder.fit_transform(d['review'])

# %%
d['review'].unique()
# Out:
# array([0, 2, 1])

# %%
d['education'] = label_encoder.fit_transform(d['education'])

# %%
d['education'].unique()
# Out:
# array([1, 2, 0])

# %%
d
# Out:
#     age  gender  review  education  purchased
# 0    30       0       0          1          0
# 1    68       0       2          2          0
# 2    70       0       1          0          0
# 3    72       0       1          0          0
# 4    16       0       0          2          0
# 5    31       0       0          1          1
# 6    18       1       1          1          0
# 7    60       0       2          1          1
# 8    65       0       0          2          0
# 9    74       1       1          2          1
# 10   98       0       1          2          1
# 11   74       1       1          2          1
# 12   51       1       2          1          0
# 13   57       0       0          1          0
# 14   15       1       2          0          1
# 15   75       1       2          2          0
# 16   59       1       2          2          1
# 17   22       0       2          2          1
# 18   19       1       1          1          0
# ...
